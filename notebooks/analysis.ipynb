# %%
import pandas as pd
import matplotlib.pyplot as plt
from pykrige import OrdinaryKriging
import numpy as np
df = pd.read_csv('data/1961-1990.csv')
print(df)
plt.scatter(df['Longitude'], df['Latitude'])
cm = plt.cm.get_cmap('viridis')
# Out:
#       Latitude   Longitude  Tmax_wt  Tmax_sp  Tmax_sm  Tmax_at  Tmin_wt  \
# 0    54.033333 -130.283333      4.4     10.0     16.0     11.1     -0.6
# 1    52.133333 -128.133333      5.4     10.9     17.3     11.7      0.6
# 2    59.450000 -135.300000     -1.4      9.6     18.4      8.3     -9.1
# 3    58.450000 -135.750000      0.3      8.1     16.6      8.2     -4.7
# 4    58.400000 -134.700000     -2.1      6.0     14.2      5.7     -8.0
# ..         ...         ...      ...      ...      ...      ...      ...
# 184  49.500000 -117.500000     -1.7      9.8     21.5      9.0     -7.6
# 185  49.500000 -116.500000     -4.4      5.3     16.9      5.8    -11.9
# 186  49.500000 -115.500000     -1.1     12.3     24.5     11.5     -9.9
# 187  48.500000 -124.500000      7.4     11.3     16.9     13.2      2.1
# 188  48.500000 -123.500000      6.0     12.6     21.1     13.4      1.0
#
#      Tmin_sp  Tmin_sm  Tmin_at  Tave_wt  Tave_sp  Tave_sm  Tave_at  PPT_wt  \
# 0        2.7      9.6      5.0      1.9      6.3     12.8      8.0     768
# 1        3.1      9.7      6.0      3.0      7.0     13.5      8.9     883
# 2       -0.7      8.4      0.8     -5.2      4.4     13.4      4.6     212
# 3        0.4      7.9      2.3     -2.2      4.3     12.3      5.3     440
# 4       -2.0      6.0     -0.1     -5.0      2.0     10.1      2.8     593
# ..       ...      ...      ...      ...      ...      ...      ...     ...
# 184     -0.6      9.0      1.0     -4.7      4.6     15.2      5.0     384
# 185     -3.6      6.3     -2.3     -8.1      0.8     11.6      1.7     374
# 186     -0.7      8.2     -0.5     -5.5      5.8     16.3      5.5     126
# 187      4.5     10.1      6.7      4.8      7.9     13.5      9.9    1055
# 188      3.9     10.3      5.9      3.5      8.3     15.7      9.6     474
#
#      PPT_sp  PPT_sm  PPT_at    TD
# 0       549     343     906  12.7
# 1       649     416     973  11.7
# 2       135     140     327  21.1
# 3       260     288     652  16.5
# 4       443     474     947  17.0
# ..      ...     ...     ...   ...
# 184     225     172     284  22.3
# 185     223     183     290  21.9
# 186     104     123     108  24.7
# 187     524     202     768   9.9
# 188     182      69     311  13.7
#
# [189 rows x 19 columns]
# /var/folders/f_/clm45k0n4nl4ybff530ct64m0000gn/T/ipykernel_63662/891398920.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cm = plt.cm.get_cmap('viridis')

# %%
plt.figure(figsize=(10,10))
scatter = plt.scatter(df['Longitude'], df['Latitude'], c = df['Tave_at'], cmap=cm, s=50)
plt.colorbar(scatter)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Show plot
# plt.show()

# %%
OK = OrdinaryKriging(x=df['Longitude'], 
                      y=df['Latitude'], 
                      z=df['Tave_at'],
                      variogram_model='exponential',
                      verbose=True, enable_plotting=True,
                      coordinates_type='geographic')
# Out:
# Plotting Enabled
#
# Initializing variogram model...
# Coordinates type: 'geographic'
#
# Using 'exponential' Variogram Model
# Partial Sill: 17.124604748646426
# Full Sill: 17.124604748646433
# Range: 10.86231430856694
# Nugget: 6.936201498357502e-15
# Calculating statistics on variogram model fit...
